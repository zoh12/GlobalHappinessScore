# %%
import pandas as pd
import os
import glob
import re
import transform_files as transform

# # extract and merge all csv files
# data_path = r'dataFiles'
# csv_files = glob.glob(data_path + "/*.csv")
# li = []

# for filename in csv_files:
#     file_year = re.search(r'\d+', filename).group(0)
#     if file_year!= '2015':
#         df = pd.read_csv(filename, index_col=None, header=0)
#         df['Year'] = file_year
#         df = transform.rename_cols(df)
#         # df.rename(columns={"Happiness Score":"Score"}, inplace = True)
#         df = transform.reorder_cols(df)
#         li.append(df)
# happiness_df = pd.concat(li,ignore_index=True)
# happiness_df = happiness_df.sort_values(by="Year")
# # replace null with 0
# happiness_df['Social support'] = happiness_df['Social support'].fillna(0)
# happiness_df['Family'] = happiness_df['Family'].fillna(0)
# happiness_df. drop('Score', axis=1, inplace=True)
# #save to new csv file
# happiness_df.to_csv('happiness.csv')
# display(happiness_df)
# display(happiness_df.groupby('Year').count())

#extract json file
json_df = pd.read_json("dataFiles/countries_continents_codes_flags_url.json")
json_df = transform.float_to_int(json_df)
json_df.to_csv('country.csv')
display(json_df)
# Out:
#                                   country              images_file  \
# 0                             Afghanistan  Flag_of_Afghanistan.svg
# 1                                 Albania      Flag_of_Albania.svg
# 2                                 Algeria      Flag_of_Algeria.svg
# 3                                 Andorra      Flag_of_Andorra.svg
# 4                                  Angola       Flag_of_Angola.svg
# ..                                    ...                      ...
# 268  United States Minor Outlying Islands
# 269              Virgin Islands (British)
# 270                 Virgin Islands (U.S.)
# 271                     Wallis and Futuna
# 272                        Western Sahara
#
#                                              image_url alpha-2 alpha-3  \
# 0    https://upload.wikimedia.org/wikipedia/commons...      AF     AFG
# 1    https://upload.wikimedia.org/wikipedia/commons...      AL     ALB
# ...
